# %%
import os
import json
import requests
import pandas as pd

# %%
import sys
sys.path.insert(0, '/home/rparulkar/libs/data-collection/api')
import api as five3api

# %%
import time
from datetime import timedelta

# %%
SOURCEDIR = 'source-data/'
OUTDIR = 'processed-data/'

# %%
project_codes_inf = os.path.join(SOURCEDIR, 'tissueSourceSite.tsv')
project_codes_df = pd.read_csv(project_codes_inf, dtype=str, sep='\t')
project_codes_df
# Out:
#     TSS Code                                        Source Site  \
# 0         01                  International Genomics Consortium
# 1         02                          MD Anderson Cancer Center
# 2         04                         Gynecologic Oncology Group
# 3         05                                          Indivumed
# 4         06                                Henry Ford Hospital
# 5         07                                               TGen
# 6         08                                               UCSF
# 7         09                                               UCSF
# 8         10                          MD Anderson Cancer Center
# 9         11                          MD Anderson Cancer Center
# 10        12                                               Duke
# 11        13                           Memorial Sloan Kettering
# 12        14                                   Emory University
# 13        15                            Mayo Clinic - Rochester
# 14        16                           Toronto Western Hospital
# 15        17                              Washington University
# 16        18                Princess Margaret Hospital (Canada)
# 17        19                                       Case Western
# 18        1Z                                      Johns Hopkins
# 19        20                            Fox Chase Cancer Center
# 20        21                            Fox Chase Cancer Center
# 21        22                            Mayo Clinic - Rochester
# 22        23                                       Cedars Sinai
# 23        24                              Washington University
# 24        25                            Mayo Clinic - Rochester
# 25        26                              University of Florida
# 26        27  Milan - Italy, Fondazione IRCCS Instituto Neur...
# 27        28                                       Cedars Sinai
# 28        29                                               Duke
# 29        2A             Memorial Sloan Kettering Cancer Center
# ..       ...                                                ...
# 800       YY                                       Roswell Park
# 801       YZ                          The Ohio State University
# 802       Z2                                          IDI-IRCCS
# 803       Z3                                               UCLA
# 804       Z4                                           Cureline
# 805       Z5                                           Cureline
# 806       Z6                                           Cureline
# 807       Z7                           John Wayne Cancer Center
# 808       Z8                           John Wayne Cancer Center
# 809       ZA                                            Candler
# 810       ZB                                       Thoraxklinik
# 811       ZC                             University of Mannheim
# 812       ZD                                             ILSbio
# 813       ZE                                    Spectrum Health
# 814       ZF                            University of Sheffield
# 815       ZG        University Medical Center Hamburg-Eppendorf
# 816       ZH                       University of North Carolina
# 817       ZJ                                     NCI HRE Branch
# 818       ZK                           University of New Mexico
# 819       ZL                                    Valley Hospital
# 820       ZM                                  University of Ulm
# 821       ZN  Brigham and Women's Hospital Division of Thora...
# 822       ZP                       Medical College of Wisconsin
# 823       ZQ                                Tayside Tissue Bank
# 824       ZR                                Tayside Tissue Bank
# 825       ZS                                Tayside Tissue Bank
# 826       ZT                  International Genomics Consortium
# 827       ZU                                    Spectrum Health
# 828       ZW                              University of Alabama
# 829       ZX                              University of Alabama
#
#                                             Study Name  BCR
# 0                    Ovarian serous cystadenocarcinoma  IGC
# 1                              Glioblastoma multiforme  IGC
# 2                    Ovarian serous cystadenocarcinoma  IGC
# 3                                  Lung adenocarcinoma  IGC
# 4                              Glioblastoma multiforme  IGC
# 5                                    Cell Line Control  IGC
# 6                              Glioblastoma multiforme  IGC
# 7                    Ovarian serous cystadenocarcinoma  IGC
# 8                    Ovarian serous cystadenocarcinoma  IGC
# 9                         Lung squamous cell carcinoma  IGC
# 10                             Glioblastoma multiforme  IGC
# 11                   Ovarian serous cystadenocarcinoma  IGC
# 12                             Glioblastoma multiforme  IGC
# 13                             Glioblastoma multiforme  IGC
# 14                             Glioblastoma multiforme  IGC
# 15                                 Lung adenocarcinoma  IGC
# 16                        Lung squamous cell carcinoma  IGC
# 17                             Glioblastoma multiforme  IGC
# 18                                             Thymoma  NCH
# 19                   Ovarian serous cystadenocarcinoma  IGC
# 20                        Lung squamous cell carcinoma  IGC
# 21                        Lung squamous cell carcinoma  IGC
# 22                   Ovarian serous cystadenocarcinoma  IGC
# 23                   Ovarian serous cystadenocarcinoma  IGC
# 24                   Ovarian serous cystadenocarcinoma  IGC
# 25                             Glioblastoma multiforme  IGC
# 26                             Glioblastoma multiforme  IGC
# 27                             Glioblastoma multiforme  IGC
# 28                   Ovarian serous cystadenocarcinoma  IGC
# 29                             Prostate adenocarcinoma  NCH
# ..                                                 ...  ...
# 800                          Pancreatic adenocarcinoma  NCH
# 801                                     Uveal Melanoma  NCH
# 802                            Skin Cutaneous Melanoma  NCH
# 803                                            Sarcoma  NCH
# 804                                            Sarcoma  NCH
# 805                          Pancreatic adenocarcinoma  NCH
# 806                              Esophageal carcinoma   NCH
# 807                          Breast invasive carcinoma  NCH
# 808                          Pancreatic adenocarcinoma  NCH
# 809                             Stomach adenocarcinoma  NCH
# 810                                            Thymoma  NCH
# 811                                            Thymoma  NCH
# 812                                 Cholangiocarcinoma  NCH
# 813                       Lung squamous cell carcinoma  NCH
# 814                       Bladder Urothelial Carcinoma  NCH
# 815                            Prostate adenocarcinoma  NCH
# 816                                 Cholangiocarcinoma  NCH
# 817  Cervical squamous cell carcinoma and endocervi...  NCH
# 818                                 Cholangiocarcinoma  NCH
# 819                                            Thymoma  NCH
# 820                        Testicular Germ Cell Tumors  NCH
# 821                                       Mesothelioma  NCH
# 822                     Liver hepatocellular carcinoma  NCH
# 823                             Stomach adenocarcinoma  NCH
# 824                              Esophageal carcinoma   NCH
# 825                     Liver hepatocellular carcinoma  NCH
# 826                                            Thymoma  NCH
# 827                                 Cholangiocarcinoma  NCH
# 828                          Pancreatic adenocarcinoma  NCH
# 829  Cervical squamous cell carcinoma and endocervi...  NCH
#
# [830 rows x 4 columns]

# %%
data = json.load(open(os.path.join(SOURCEDIR, '20180823_release_12.0.clean.json')))
print '# of patients: {0}'.format(str(len(data.keys())))
print '# of unique patients?: {0}'.format(str(len(list(set(data.keys())))))
# Out:
# # of patients: 11167
# # of unique patients?: 11167

# %% [markdown]
# # Nant Drug DB

# %%
DRUG_AUTH = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyX2lkIjo1MCwiZW1haWwiOiJyYWh1bC5wYXJ1bGthckBpbW11bml0eWJpby5jb20iLCJ1c2VybmFtZSI6InJhaHVsLnBhcnVsa2FyQGltbXVuaXR5YmlvLmNvbSIsImV4cCI6MTU5NDg4NTM0MSwib3JpZ19pYXQiOjE1OTQ4NDIxNDF9.Fkq_sTWspcPbNAoQ0AH5FyR2LxMERLT3b3IrJejfWPQ'
DRUG_URL = 'https://drugs.nantomics.com/api/drugs'
r, code = five3api.query(DRUG_URL, auth=DRUG_AUTH, authtype='JWT')
r_json = r.json()
drug_results = five3api.reports_paginated(r_json, [], auth=DRUG_AUTH, authtype='JWT')

# %%
len(drug_results)

# %%
nant_drugs_aliases = {x['name']: [drug.lstrip(' ').rstrip(' ') for drug in x['synonyms'].split('|')] + [x['name']] for x in drug_results}

# %% [markdown]
# # Pubchem Drug DB

# %%
pubchem_drugs_aliases = {}
aliases_not_found = []

start_time = time.time()
ngroups = len(nant_drugs_aliases.keys())
nparsed = 1

for alias in nant_drugs_aliases.keys():
    response = requests.get('https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/{0}/synonyms/JSON'.format(alias))
    if response.status_code == 200:
        pubchem_drugs_aliases[alias] = response.json()['InformationList']['Information'][0]['Synonym']
    else:
        aliases_not_found.append(alias)
    
    if nparsed % ngroups != 0:
        sys.stdout.write("\r%d/%d parsed [%.2f%% complete]" % (nparsed, ngroups, 100*float(nparsed)/ngroups))
        sys.stdout.flush()
    nparsed += 1

sys.stdout.write("Elapsed time: %s" % str(timedelta(seconds=(time.time() - start_time))))

# %%
print len(aliases_not_found)
print aliases_not_found[0]

# %% [markdown]
# ## Write out aliases

# %%
combined_aliases = {}
for tx in nant_drugs_aliases.keys():
    aliases = nant_drugs_aliases.get(tx, []) + pubchem_drugs_aliases.get(tx, [])
    aliases = list(set(aliases))
    combined_aliases[tx] = aliases

aliases_out = os.path.join(OUTDIR, 'aliases.json')
with open(aliases_out, 'w') as fp:
    json.dump([combined_aliases], fp, indent=4)

# %% [markdown]
# # TCGA Patient Class

# %%
class TCGAPatient:
    def __init__(self, uuid, d):
        self.info = d
        self.uuid = uuid
        self.barcode = self.get_field('bcr_patient_barcode', DEFAULT='NA')
        self.age = 'NA' if not self.get_age() else self.get_age()
        self.gender = self.get_field('gender', DEFAULT='NA')
        self.tissue = self.get_field('tumor_tissue_site', DEFAULT='NA')
        self.race = self.get_field('race', DEFAULT='NA')
        self.project = self.get_project()
        self.collection = self.get_collection_type() 
        
    def get_field(self, key, DEFAULT=None):
        return self.info.get(key, DEFAULT)

    def get_age(self):
        return (self.get_field('age_at_diagnosis', None) or 
                    self.get_field('age_at_initial_pathologic_diagnosis', None))
    
    def get_project(self):
        project_code = self.barcode.split('-')[1]
        if project_code in project_codes_df['TSS Code'].unique():
            return project_codes_df[project_codes_df['TSS Code'] == project_code]['Study Name'].tolist()[0]
        else:
            return 'NA'
        
    def get_collection_type(self):
        collection_type = 'NA'
        if (self.get_field('retrospective_collection') and not 
                self.get_field('prospective_collection')):
            collection_type = 'retrospective'
        elif (not self.get_field('retrospective_collection') and 
                  self.get_field('prospective_collection')):
            collection_type = 'prospective'
        return collection_type
    
    def get_vital(self):
        LCDT = 'last_contact_days_to' # Alive + Dead
        DTLF = 'days_to_last_followup' # Alive + Dead
        DDT = 'death_days_to' # Dead only
        DTD = 'days_to_death' # Dead only
        
        times = [(val, key) for val, key in self.os_times if val != '']
        
        if (len(times) == 0 and 
                self.get_field('vital_status', '') == ''):
            return 'NA'
        elif any([key in [DDT, DTD] for time, key in times]):
            return 'Dead'
        else:
            return 'Alive'
    
    def get_nlp_values(self):
        nlp_keys = ['age at diagnosis', 'age at initial pathologic diagnosis',
                    'ajcc clinical tumor stage', 'ajcc pathologic tumor stage',
                    'bilateral diagnosis timing type',
                    'breslow thickness at diagnosis', 'clark level at diagnosis',
                    'clinical stage', 'days to initial pathologic diagnosis',
                    'diabetes diagnosis days to', 'diabetes diagnosis indicator',
                    'grade tier system', 'height cm at diagnosis',
                    'histologic diagnosis', 'histologic diagnosis other',
                    'histologic diagnosis percent', 'hypertension diagnosis',
                    'igcccg stage', 'initial diagnosis esophageal ca type',
                    'initial pathologic diagnosis method', 'masaoka stage',
                    'neoplasm histologic grade', 'nuclear grade III IV',
                    'pregnant at diagnosis', 'surgical approach at diagnosis',
                    'tumor grade', 'weight kg at diagnosis',
                    'year of initial pathologic diagnosis']
        nlp_values = [self.get_field('_'.join(key.split(' ')), 'None') for key in nlp_keys]
        return nlp_values

######## OS ########
    
    def get_os_event_time(self): # OS ONLY?
        if self.vital == 'NA':
            return 'NA'
        
        LCDT = 'last_contact_days_to' # Alive + Dead
        DTLF = 'days_to_last_followup' # Alive + Dead
        DDT = 'death_days_to' # Dead only
        DTD = 'days_to_death' # Dead only
        
        BLACKLIST = ["[Discrepancy]", "[Completed]"]
        times = [(int(val), key) for val, key in self.os_times if val not in BLACKLIST and val != '']
        
        if len(times) == 0:
            return 'NA'
        
        max_time = max([time for time, key in times])
        for time, key in times:
            if (time == max_time and 
                    self.vital == 'Alive' and
                    key in [LCDT, DTLF]):
                return max_time
            elif (time == max_time and 
                    self.vital == 'Dead' and
                    key in [DDT, DTD]):
                return max_time
    
    def get_os_censored(self): # OS ONLY?
        LCDT = 'last_contact_days_to' # Alive + Dead
        DTLF = 'days_to_last_followup' # Alive + Dead
        DDT = 'death_days_to' # Dead only
        DTD = 'days_to_death' # Dead only
        
        BLACKLIST = ["[Discrepancy]", "[Completed]"]
        times = [(int(val), key) for val, key in self.os_times if val not in BLACKLIST and val != '']
        
        if len(times) == 0:
            return 'True'
        else:
            max_time = max([time for time, key in times])
            if any([True for time, key in times if time == max_time and key in [DDT, DTD]]):
                return 'False'
            else:
                return 'True'
        
    def get_os_times(self, field='patient'):
        
        BLACKLIST = ["[Discrepancy]", "[Completed]"]
        
        LCDT = 'last_contact_days_to' # Alive + Dead
        DTLF = 'days_to_last_followup' # Alive + Dead
        DDT = 'death_days_to' # Dead only
        DTD = 'days_to_death' # Dead only
        
        KEYS = [LCDT, DTLF, DDT, DTD]
        if (field == 'patient' and 
                self.info.get('vital_status', None)):
            d = self.info
            vals = [(str(d.get(KEY, '')), KEY) for KEY in KEYS]
        elif (field == 'followups' and 
                  field in self.info):
            followups = self.get_field(field)
            vals = []
            for d in followups:
                if d.get('vital_status', None):
                    for KEY in KEYS:
                        vals.append((str(d.get(KEY, '')), KEY))
        else:
            return []
        
        return vals

######## END OS ########

# %%
patients = []
for uuid in data:
    d = data[uuid]
    p = TCGAPatient(uuid, d)
    p.os_times = list(set(p.get_os_times() + p.get_os_times(field='followups')))
    p.vital = p.get_vital()
    p.os_censored = p.get_os_censored()
    p.os_time = p.get_os_event_time()
    
    ### NLP Fields ###
    nlp_values = p.get_nlp_values()
    
    patients.append(tuple([p.uuid, p.barcode, p.age, p.gender,
# 11165  81648978-A543-4EAE-8848-98DDF1CB832B  TCGA-06-A5U1  78  FEMALE
# 11166  c2aeee6c-ba10-4cf9-b560-c739580f7bf3  TCGA-BH-A0BM  54  FEMALE
#
#                                                   tissue  \
# 0                                                  Liver
# 1                                                  Brain
# 2                                               Prostate
# 3                                                Bladder
# 4                                               Prostate
# 5      Retroperitoneum/Upper abdominal - Retroperitoneum
# 6                                                  Brain
# 7                                                     NA
# 8                                                     NA
# 9                                                   Lung
# 10                                               Stomach
# 11                                                Breast
# 12                                                 Liver
# 13                                                 Ovary
# 14                                               Stomach
# 15                                             Esophagus
# 16                                               Choroid
# 17                                                Breast
# 18                                                 Ovary
# 19                                               Bladder
# 20                                               Choroid
# 21                                                Pleura
# 22                                                    NA
# 23                                                    NA
# 24                                                    NA
# 25                                         Head and Neck
# 26                                                 Colon
# 27                                                    NA
# 28                                           Endometrial
# 29                                                 Ovary
# ...                                                  ...
# 11137                                                 NA
# 11138                                        Endometrial
# 11139                                           Prostate
# 11140                                        Endometrial
# 11141                                            Stomach
# 11142                                              Brain
# 11143                                              Liver
# 11144                                                 NA
# 11145                                      Head and Neck
# 11146                                             Kidney
# 11147                                            Bladder
# 11148                                             Kidney
# 11149                                            Thyroid
# 11150                                             Breast
# 11151                                        Endometrial
# 11152                                               Lung
# 11153                                              Brain
# 11154                                           Prostate
# 11155                                             Rectum
# 11156                                              Ovary
# 11157                                              Liver
# 11158                                            Bladder
# 11159                                                 NA
# 11160  Retroperitoneum/Upper abdominal - Retroperitoneum
# 11161                                        Bone Marrow
# 11162                                              Colon
# 11163                                             Kidney
# 11164                                      Head and Neck
# 11165                                              Brain
# 11166                                             Breast
#
#                                      project                       race  \
# 0             Liver hepatocellular carcinoma                      ASIAN
# 1                    Glioblastoma multiforme  BLACK OR AFRICAN AMERICAN
# 2                    Prostate adenocarcinoma  BLACK OR AFRICAN AMERICAN
# 3               Bladder Urothelial Carcinoma                      WHITE
# 4                    Prostate adenocarcinoma                      WHITE
# 5                                    Sarcoma                      WHITE
# 6                    Glioblastoma multiforme                      WHITE
# 7                        Lung adenocarcinoma                      WHITE
# 8                        Lung adenocarcinoma                         NA
# 9               Lung squamous cell carcinoma                      WHITE
# 10                    Stomach adenocarcinoma                      ASIAN
# 11                 Breast invasive carcinoma                      WHITE
# 12            Liver hepatocellular carcinoma                      WHITE
# 13         Ovarian serous cystadenocarcinoma                      WHITE
# 14                    Stomach adenocarcinoma                         NA
# 15                     Esophageal carcinoma                       WHITE
# 16                            Uveal Melanoma                         NA
# 17                 Breast invasive carcinoma                      WHITE
# 18         Ovarian serous cystadenocarcinoma                      WHITE
# 19              Bladder Urothelial Carcinoma                      WHITE
# 20                            Uveal Melanoma                      WHITE
# 21                              Mesothelioma                      WHITE
# 22                       Lung adenocarcinoma                      WHITE
# 23                   Skin Cutaneous Melanoma                      WHITE
# 24                       Lung adenocarcinoma                      WHITE
# 25     Head and Neck squamous cell carcinoma                      WHITE
# 26                      Colon adenocarcinoma                         NA
# 27        Pheochromocytoma and Paraganglioma                      WHITE
# 28      Uterine Corpus Endometrial Carcinoma                         NA
# 29         Ovarian serous cystadenocarcinoma                         NA
# ...                                      ...                        ...
# 11137                Skin Cutaneous Melanoma                      WHITE
# 11138   Uterine Corpus Endometrial Carcinoma                      WHITE
# 11139                Prostate adenocarcinoma                      WHITE
# 11140   Uterine Corpus Endometrial Carcinoma                      WHITE
# 11141                 Stomach adenocarcinoma                      WHITE
# 11142                Glioblastoma multiforme  BLACK OR AFRICAN AMERICAN
# 11143         Liver hepatocellular carcinoma                      WHITE
# 11144     Pheochromocytoma and Paraganglioma                      WHITE
# 11145  Head and Neck squamous cell carcinoma                      WHITE
# 11146      Kidney renal clear cell carcinoma                      WHITE
# 11147           Bladder Urothelial Carcinoma  BLACK OR AFRICAN AMERICAN
# 11148      Kidney renal clear cell carcinoma  BLACK OR AFRICAN AMERICAN
# 11149                      Thyroid carcinoma                      WHITE
# 11150              Breast invasive carcinoma                      WHITE
# 11151   Uterine Corpus Endometrial Carcinoma                      WHITE
# 11152           Lung squamous cell carcinoma                      WHITE
# 11153                Glioblastoma multiforme                      WHITE
# 11154                Prostate adenocarcinoma                      WHITE
# 11155                  Rectum adenocarcinoma                         NA
# 11156      Ovarian serous cystadenocarcinoma                      WHITE
# 11157         Liver hepatocellular carcinoma                      ASIAN
# 11158           Bladder Urothelial Carcinoma                      WHITE
# 11159                Skin Cutaneous Melanoma                      WHITE
# 11160                                Sarcoma                      WHITE
# 11161                 Acute Myeloid Leukemia  BLACK OR AFRICAN AMERICAN
# 11162                   Colon adenocarcinoma                      WHITE
# 11163      Kidney renal clear cell carcinoma  BLACK OR AFRICAN AMERICAN
# 11164  Head and Neck squamous cell carcinoma                      WHITE
# 11165                Glioblastoma multiforme  BLACK OR AFRICAN AMERICAN
# 11166              Breast invasive carcinoma                      WHITE
#
#       collection_type vital_status os_censored  ...  \
# 0         prospective         Dead       False  ...
# 1                  NA         Dead       False  ...
# 2       retrospective        Alive        True  ...
# 3       retrospective         Dead       False  ...
# 4         prospective        Alive        True  ...
# 5       retrospective        Alive        True  ...
# 6                  NA         Dead       False  ...
# 7         prospective         Dead       False  ...
# 8       retrospective        Alive        True  ...
# 9       retrospective        Alive        True  ...
# 10      retrospective        Alive        True  ...
# 11      retrospective        Alive        True  ...
# 12      retrospective         Dead       False  ...
# 13                 NA        Alive        True  ...
# 14      retrospective        Alive        True  ...
# 15      retrospective         Dead       False  ...
# 16      retrospective        Alive        True  ...
# 17      retrospective        Alive        True  ...
# 18                 NA        Alive        True  ...
# 19        prospective         Dead       False  ...
# 20      retrospective        Alive        True  ...
# 21      retrospective         Dead       False  ...
# 22        prospective         Dead       False  ...
# 23        prospective        Alive        True  ...
# 24      retrospective        Alive        True  ...
# 25      retrospective        Alive        True  ...
# 26      retrospective        Alive        True  ...
# 27      retrospective        Alive        True  ...
# 28      retrospective        Alive        True  ...
# 29      retrospective         Dead       False  ...
# ...               ...          ...         ...  ...
# 11137     prospective         Dead       False  ...
# 11138   retrospective         Dead       False  ...
# 11139   retrospective        Alive        True  ...
# 11140     prospective        Alive        True  ...
# 11141     prospective         Dead       False  ...
# 11142              NA         Dead       False  ...
# 11143   retrospective         Dead       False  ...
# 11144   retrospective        Alive        True  ...
# 11145     prospective        Alive        True  ...
# 11146              NA         Dead       False  ...
# 11147   retrospective         Dead       False  ...
# 11148     prospective        Alive        True  ...
# 11149   retrospective         Dead       False  ...
# 11150     prospective        Alive        True  ...
# 11151   retrospective        Alive        True  ...
# 11152   retrospective         Dead       False  ...
# 11153              NA         Dead       False  ...
# 11154   retrospective        Alive        True  ...
# 11155   retrospective         Dead       False  ...
# 11156              NA         Dead       False  ...
# 11157     prospective         Dead       False  ...
# 11158   retrospective         Dead       False  ...
# 11159   retrospective         Dead       False  ...
# 11160   retrospective         Dead       False  ...
# 11161              NA         Dead       False  ...
# 11162     prospective        Alive        True  ...
# 11163     prospective        Alive        True  ...
# 11164     prospective        Alive        True  ...
# 11165   retrospective         Dead       False  ...
# 11166   retrospective        Alive        True  ...
#
#       initial diagnosis esophageal ca type  \
# 0                                     None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# 5                                     None
# 6                                     None
# 7                                     None
# 8                                     None
# 9                                     None
# 10                                    None
# 11                                    None
# 12                                    None
# 13                                    None
# 14                                    None
# 15                             Symptomatic
# 16                                    None
# 17                                    None
# 18                                    None
# 19                                    None
# 20                                    None
# 21                                    None
# 22                                    None
# 23                                    None
# 24                                    None
# 25                                    None
# 26                                    None
# 27                                    None
# 28                                    None
# 29                                    None
# ...                                    ...
# 11137                                 None
# 11138                                 None
# 11139                                 None
# 11140                                 None
# 11141                                 None
# 11142                                 None
# 11143                                 None
# 11144                                 None
# 11145                                 None
# 11146                                 None
# 11147                                 None
# 11148                                 None
# 11149                                 None
# 11150                                 None
# 11151                                 None
# 11152                                 None
# 11153                                 None
# 11154                                 None
# 11155                                 None
# 11156                                 None
# 11157                                 None
# 11158                                 None
# 11159                                 None
# 11160                                 None
# 11161                                 None
# 11162                                 None
# 11163                                 None
# 11164                                 None
# 11165                                 None
# 11166                                 None
#
#       initial pathologic diagnosis method masaoka stage  \
# 0                                    None          None
# 1                                    None          None
# 2                      Core needle biopsy          None
# 3                                    None          None
# 4                      Core needle biopsy          None
# 5                                    None          None
# 6                                    None          None
# 7                                    None          None
# 8                                    None          None
# 9                                    None          None
# 10                                   None          None
# 11                                   None          None
# 12                                   None          None
# 13                                   None          None
# 14                                   None          None
# 15                                   None          None
# 16                                   None          None
# 17                                   None          None
# 18                                   None          None
# 19                                   None          None
# 20                                   None          None
# 21                                   None          None
# 22                                   None          None
# 23                                   None          None
# 24                                   None          None
# 25                                   None          None
# 26                                   None          None
# 27                                   None          None
# 28                                   None          None
# 29                                   None          None
# ...                                   ...           ...
# 11137                                None          None
# 11138                                None          None
# 11139                  Core needle biopsy          None
# 11140                                None          None
# 11141                                None          None
# 11142                                None          None
# 11143                                None          None
# 11144                                None          None
# 11145                                None          None
# 11146                                None          None
# 11147                                None          None
# 11148                                None          None
# 11149                                None          None
# 11150                                None          None
# 11151                                None          None
# 11152                                None          None
# 11153                                None          None
# 11154                  Core needle biopsy          None
# 11155                                None          None
# 11156                                None          None
# 11157                                None          None
# 11158                                None          None
# 11159                                None          None
# 11160                                None          None
# 11161                                None          None
# 11162                                None          None
# 11163                                None          None
# 11164                                None          None
# 11165                                None          None
# 11166                                None          None
#
#       neoplasm histologic grade nuclear grade III IV pregnant at diagnosis  \
# 0                          None                 None                  None
# 1                          None                 None                  None
# 2                          None                 None                  None
# 1                                     None
# 2                                     None
# 3                                     None
# 4                                     None
# 5                                     None
# 6                                     None
# 7                                     None
# 8                                     None
# 9                                     None
# 10                                    None
# 11                                    None
# 12                                    2002
# 13                                    None
# 14                                    None
# 15                                    None
# 16                                    None
# 17                                    None
# 18                                    None
# 19                                    None
# 20                                    None
# 21                                    None
# 22                                    None
# 23                                    None
# 24                                    None
# 25                                    None
# 26                                    None
# 27                                    None
# 28                                    None
# 29                                    None
# ...                                    ...
# 11137                                 None
# 11138                                 None
# 11139                                 None
# 11140                                 None
# 11141                                 None
# 11142                                 None
# 11143                                 2005
# 11144                                 None
# 11145                                 None
# 11146                                 None
# 11147                                 None
# 11148                                 None
# 11149                                 None
# 11150                                 None
# 11151                                 None
# 11152                                 None
# 11153                                 None
# 11154                                 None
# 11155                                 None
# 11156                                 None
# 11157                                 2013
# 11158                                 None
# 11159                                 None
# 11160                                 None
# 11161                                 None
# 11162                                 None
# 11163                                 None
# 11164                                 None
# 11165                                 None
# 11166                                 None
#
# [11167 rows x 39 columns]

# %%
patients_df['vital_status'].value_counts()
# Out:
# Alive    7549
# Dead     3610
# NA          8
# Name: vital_status, dtype: int64

# %%
patients_df.to_csv('processed-data/20180823_release_12.0.tsv', sep='\t', index=False)

# %% [markdown]
# # Drug Mapping

# %% [markdown]
# ## First, lets map based on drug entries as seen in GDC
# #### No string manipulation or best guessing of drug alias as documented in NANT or PUBCHEM

# %%
drug_mapping = {uuid: {'drugs': []} for uuid in data}
not_found = []

start_time = time.time()
ngroups = len(drug_mapping.keys())
nparsed = 1

for uuid in data:
    d = data[uuid]
    drugs = d.get('drugs', [])
    if len(drugs) > 0:
        for tx in drugs:
            tx_name = tx.get('pharmaceutical_therapy_drug_name', '')
            flag = False
            if tx_name != '':
                tx_new = str(tx_name)
                tx_new = tx_new[0].upper() + tx_new[1:].lower()
                for drug in nant_drugs_aliases.keys():
                    aliases = nant_drugs_aliases.get(drug, []) + pubchem_drugs_aliases.get(drug, [])
                    if tx_name in aliases:
                        drug_mapping[uuid]['drugs'].append(drug)
                        flag = True
                        break
                    elif tx_new in aliases :
                        drug_mapping[uuid]['drugs'].append(drug)
                        flag = True
                        break
            if not flag:
                not_found.append((uuid, tx_name))
    
    if nparsed % ngroups != 0:
        sys.stdout.write("\r%d/%d parsed [%.2f%% complete]" % (nparsed, ngroups, 100*float(nparsed)/ngroups))
        sys.stdout.flush()
    nparsed += 1

sys.stdout.write("Elapsed time: %s" % str(timedelta(seconds=(time.time() - start_time))))

# %%
print len(not_found)

# %%
print sorted([x for x in list(set(not_found))], key=lambda x: x[1])

# %%
print sorted(nant_drugs_aliases.keys())

# %%
print nant_drugs_aliases['Doxorubicin']
print pubchem_drugs_aliases['Doxorubicin']

# %%
drug_mapping_out = os.path.join(OUTDIR, 'drugs.json')
with open(drug_mapping_out, 'w') as fp:
    json.dump([drug_mapping], fp, indent=4)

# %%
count = 0
for uuid in drug_mapping.keys():
    if len(drug_mapping[uuid]['drugs']) > 0:
        count += 1
print count

# %%
drug_mapping
